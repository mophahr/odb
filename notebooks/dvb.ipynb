# %%
from __future__ import division, print_function

# %%
import sys
dir = !pwd
dir = '/'.join(dir[0].split('/')[:-1])
sys.path.append(dir+"/foreign/dvb/")
import dvb

# %%
dvb.route("Albertplatz", 'Mickten')
# Out:
# {'destination': u'Dresden, Mickten',
#  'origin': u'Dresden, Albertplatz',
#  'trips': [{'arrival': u'22:37',
#    'departure': u'22:22',
#    'duration': u'00:15',
#    'interchange': 1,
#    'nodes': [{'arrival': {'coords': u'13750379,51071071',
#       'stop': u'Bischofsweg',
#       'time': u'22:25'},
#      'departure': {'coords': u'13746500,51063164',
#       'stop': u'Albertplatz',
#       'time': u'22:22'},
#      'direction': u'Weixdorf (Rathenaustra\xdfe, Gleisschleife)',
#      'line': u'7',
#      'mode': u'Stra\xdfenbahn',
#      'path': [[13.746514, 51.063164],
#       [13.746545, 51.063226],
#       [13.746608, 51.063378],
#       [13.746793, 51.063753],
#       [13.746826, 51.064229],
#       [13.746855, 51.064633],
#       [13.746965, 51.066043],
#       [13.747013, 51.066564],
#       [13.747394, 51.067574],
#       [13.747469, 51.06768],
#       [13.747469, 51.06768],
#       [13.747711, 51.068027],
#       [13.748234, 51.068658],
#       [13.748488, 51.068969],
# ...
